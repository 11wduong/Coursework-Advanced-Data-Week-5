# %%
import pandas as pd
import pymysql
import os
from dotenv import load_dotenv

from extract import get_db_connection, extract_table_data, extract_all_data, main
from transform import combine_tables, clean_table, calculate_averages, create_outlier_df

# %%
load_dotenv()
data = main()
# Out:
# Connecting to database...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 load_dotenv()
# ----> 2 data = main()
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/archive_pipeline/extract.py:54, in main()
#      52 """Main function to extract all database data."""
#      53 print("Connecting to database...")
# ---> 54 conn = get_db_connection()
#      56 try:
#      57     print("\nExtracting data from all tables...")
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/archive_pipeline/extract.py:20, in get_db_connection()
#      17 db_user = os.getenv("DB_USER")
#      18 db_password = os.getenv("DB_PASSWORD")
# ---> 20 conn = pymysql.connect(
#      21     host=db_host,
#      22     port=int(db_port),
#      23     user=db_user,
#      24     password=db_password,
#      25     database=db_name
#      26 )
#      28 return conn
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/archive_pipeline/.venv/lib/python3.14/site-packages/pymysql/connections.py:365, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     363     self._sock = None
#     364 else:
# --> 365     self.connect()
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/archive_pipeline/.venv/lib/python3.14/site-packages/pymysql/connections.py:680, in Connection.connect(self, sock)
#     677 self._rfile = sock.makefile("rb")
#     678 self._next_seq_id = 0
# --> 680 self._get_server_information()
#     681 self._request_authentication()
#     683 # Send "SET NAMES" query on init for:
#     684 # - Ensure charaset (and collation) is set to the server.
#     685 #   - collation_id in handshake packet may be ignored.
#    (...)    694 # - https://github.com/wagtail/wagtail/issues/9477
#     695 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/archive_pipeline/.venv/lib/python3.14/site-packages/pymysql/connections.py:1099, in Connection._get_server_information(self)
#    1097 def _get_server_information(self):
#    1098     i = 0
# -> 1099     packet = self._read_packet()
#    1100     data = packet.get_all_data()
#    1102     self.protocol_version = data[i]
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/archive_pipeline/.venv/lib/python3.14/site-packages/pymysql/connections.py:751, in Connection._read_packet(self, packet_type)
#     749 buff = bytearray()
#     750 while True:
# --> 751     packet_header = self._read_bytes(4)
#     752     # if DEBUG: dump_packet(packet_header)
#     754     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/archive_pipeline/.venv/lib/python3.14/site-packages/pymysql/connections.py:789, in Connection._read_bytes(self, num_bytes)
#     787 while True:
#     788     try:
# --> 789         data = self._rfile.read(num_bytes)
#     790         break
#     791     except OSError as e:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py:725, in SocketIO.readinto(self, b)
#     723     raise OSError("cannot read from timed out object")
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#     727     self._timeout_occurred = True
#
# KeyboardInterrupt:
