# %%
import requests
import pandas as pd

from extract import fetch_plant_data, flatten_plant_data, extract_all_plants
from transform import create_country_table, create_botanist_table, create_location_table, create_plant_table, create_record_table

# %%
df = extract_all_plants(1, 50)
# Out:
# Error fetching plant ID 7: plant not found
# Error fetching plant ID 40: plant sensor fault
# Error fetching plant ID 43: plant on loan to another museum
# Error fetching plant ID 45: plant sensor fault

# %%
create_country_table(df).head()
# Out:
#    country_id                               country
# 0           1                              Suriname
# 1           2  United States Minor Outlying Islands
# 2           3                           New Zealand
# 3           4                                Latvia
# 4           5                      Pitcairn Islands

# %%
create_botanist_table(df).head()
# Out:
#    botanist_id       botanist_name                          email  \
# 0            1     Sherry Campbell     sherry.campbell@lnhm.co.uk
# 1            2     Jacob Hernandez     jacob.hernandez@lnhm.co.uk
# 2            3  Elizabeth Crawford  elizabeth.crawford@lnhm.co.uk
# 3            4          Alan Grant          alan.grant@lnhm.co.uk
# 4            5  Jennifer Blanchard  jennifer.blanchard@lnhm.co.uk
#
#                    phone
# 0   +1-662-659-8097x8928
# 1             8268602780
# 2  001-222-509-7760x0558
# 3             6152878920
# 4           327.732.2111

# %%
create_location_table(df)
# Out:
#     location_id                  city          lat         long  country_id
# 0             1          Mitchellfurt   81.2003535     7.815683           1
# 1             2             Lake Jill    62.501933   -20.640567           2
# 2             3           Edwardsstad  -73.9289085  -106.786584           3
# 3             4           East Sherry    23.701525   106.401108           4
# 4             5       Lake Lydiaburgh   17.7169705   -17.829700           5
# 5             6          South Thomas   -65.203977  -124.152631           6
# 6             7            South Tina  -60.9363685  -152.763324           7
# 7             8           Gambleshire  -42.9962205  -123.053507           8
# 8             9           Stevensberg  -82.3459075   -13.080896           9
# 9            10           Flowersberg  -72.9649155   127.183588          10
# 10           11            Gomezmouth  -40.5645435    83.998008          11
# 11           12             Millerton  -32.9029575  -146.302804          12
# 12           13            Watsontown  -18.6871435    57.450992          13
# 13           14              Leeville  -62.5511245  -161.813034          14
# 14           15          West Melanie    64.383879    92.902187          15
# 15           16               Leebury     2.146164    56.967894          16
# 16           17            Lake Tyler   -39.502295    -0.109342          17
# 17           18         Gonzalezhaven   -67.269697   102.225776          18
# 18           19           New Yolanda  -23.4958555   -16.242039          19
# 19           20       West Kevinburgh  -69.5795405   -54.074219          20
# 20           21          East Rebecca  -34.9328045   150.371647          21
# 21           22         Mortonborough  -31.6079135   -83.850347          22
# 22           23    Lake Alexandraside    41.085675    -4.167175          23
# 23           24            Farmerberg   76.6820215   164.980551          24
# 24           25          Schmidtmouth   -29.066297    18.278546          25
# 25           26             Ruizmouth    21.876417   -31.458582          26
# 26           27          Mallorymouth     9.707351    72.816634          27
# 27           28        West Jacobfort   36.0357895   148.718821          28
# 28           29       Lake Nicolefort   47.3941165   -24.434894          29
# 29           30           South Haley  -54.5020945  -127.026269          30
# 30           31             Joanmouth  -35.3487675   -80.319921          31
# 31           32        New Thomastown    23.490859   -19.275947          32
# 32           33        Michaelborough   -23.513493    91.272237          33
# 33           34      New Shanechester   -60.291449   -12.594265          34
# 34           35            Port Jason   50.7844445   177.490752          35
# 35           36             New Diana   15.4607085   -46.580627          36
# 36           37           Schmidtfurt   -24.459428  -132.113354          37
# 37           38            South Erik    39.852798   -22.673609          38
# 38           39  Lake Christopherberg   24.7269645    -7.878364          39
# 39           40             Davidfurt   -79.460413    77.002058          40
# 40           41            Davidshire   55.3241195   145.548092          15
# 41           42              New Lori    52.915803  -138.082562          38
# 42           43         South Michael    28.275200   -60.488715          41
# 43           44         New Laurafurt   73.4670145    85.125030          40
# 44           45           Amandahaven   54.8268295  -101.575928          42
# 45           46      North Joshuatown  -73.7987385   -22.615264          39

# %%
create_plant_table(df)
# Out:
#     plant_id                      scientific_name  \
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5                 Sarracenia catesbaei
# 5          6                     Wollemia nobilis
# 6          7  Heliconia schiedeana 'Fire and Ice'
# 7          8                 Pereskia grandifolia
# 8          9
# 9         10                Asclepias curassavica
# 10        11
# 11        12
# 12        13                  Colocasia esculenta
# 13        14
# 14        15                Euphorbia cotinifolia
# 15        16                      Ipomoea batatas
# 16        17
# 17        18                          Musa basjoo
# 18        19                     Salvia splendens
# 19        20                 Anthurium andraeanum
# 20        21  Heliconia schiedeana 'Fire and Ice'
# 21        22                  Cordyline fruticosa
# 22        23                         Ficus carica
# 23        24
# 24        25                Dieffenbachia seguine
# 25        26                Spathiphyllum (group)
# 26        27                  Codiaeum variegatum
# 27        28                            Aloe vera
# 28        29                       Ficus elastica
# 29        30              Sansevieria trifasciata
# 30        31              Philodendron hederaceum
# 31        32                Schefflera arboricola
# 32        33                 Aglaonema commutatum
# 33        34                   Monstera deliciosa
# 34        35                   Tacca integrifolia
# 35        36
# 36        37                 Saintpaulia ionantha
# 37        38                Gaillardia aestivalis
# 38        39                     Caladium bicolor
# 39        40      Chlorophytum comosum 'Vittatum'
# 40        41               Araucaria heterophylla
# 41        42                  Medinilla magnifica
# 42        43            Calliandra haematocephala
# 43        44               Zamioculcas zamiifolia
# 44        45                       Crassula ovata
# 45        46                    Epipremnum aureum
#
#                       common_name  location_id
# 0                   Venus flytrap            1
# 1                   Corpse flower            2
# 2              Rafflesia arnoldii            3
# 3                Black bat flower            4
# 4                   Pitcher plant            5
# 5                    Wollemi pine            6
# 6                Bird of paradise            7
# 7                          Cactus            8
# 8                     Dragon tree            9
# 9           Asclepias Curassavica           10
# 10           Brugmansia X Candida           11
# 11                Canna ‘Striata’           12
# 12            Colocasia Esculenta           13
# 13          Cuphea ‘David Verity’           14
# 14          Euphorbia Cotinifolia           15
# 15                Ipomoea Batatas           16
# 16  Manihot Esculenta ‘Variegata’           17
# 17                    Musa Basjoo           18
# 18               Salvia Splendens           19
# 19                      Anthurium           20
# 20               Bird of Paradise           21
# 21            Cordyline Fruticosa           22
# 22                          Ficus           23
# 23                     Palm Trees           24
# 24          Dieffenbachia Seguine           25
# 25                  Spathiphyllum           26
# 26                         Croton           27
# 27                      Aloe Vera           28
# 28                 Ficus Elastica           29
# 29        Sansevieria Trifasciata           30
# 30        Philodendron Hederaceum           31
# 31          Schefflera Arboricola           32
# 32           Aglaonema Commutatum           33
# 33             Monstera Deliciosa           34
# 34             Tacca Integrifolia           35
# 35             Psychopsis Papilio           36
# 36           Saintpaulia Ionantha           37
# 37                     Gaillardia           38
# 38               Caladium Bicolor           39
# 39           Chlorophytum Comosum           40
# 40         Araucaria Heterophylla           41
# 41            Medinilla Magnifica           42
# 42      Calliandra Haematocephala           43
# 43         Zamioculcas Zamiifolia           44
# 44                 Crassula Ovata           45
# 45              Epipremnum Aureum           46

# %%
create_record_table(df).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 create_record_table(df).head()
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/transform.py:91, in create_record_table(df)
#      88 botanist_df = create_botanist_table(df)
#      89 record_df = df[['scientific_name', 'botanist_name', 'recording_taken',
#      90                 'moisture', 'temperature', 'last_watered']].reset_index(drop=True)
# ---> 91 record_df = record_df.merge(plant_df, on='scientific_name', how='left')
#      92 record_df = record_df.merge(botanist_df, on='botanist_name', how='left')
#      93 record_df['id'] = record_df.index + 1
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/.venv/lib/python3.14/site-packages/pandas/core/frame.py:12884, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   12880 self._check_copy_deprecation(copy)
#   12882 from pandas.core.reshape.merge import merge
# > 12884 return merge(
#   12885     self,
#   12886     right,
#   12887     how=how,
#   12888     on=on,
#   12889     left_on=left_on,
#   12890     right_on=right_on,
#   12891     left_index=left_index,
#   12892     right_index=right_index,
#   12893     sort=sort,
#   12894     suffixes=suffixes,
#   12895     indicator=indicator,
#   12896     validate=validate,
#   12897 )
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:399, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     384 else:
#     385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#    (...)    397         validate=validate,
#     398     )
# --> 399     return op.get_result()
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:1141, in _MergeOperation.get_result(self)
#    1138 if self.indicator:
#    1139     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# -> 1141 join_index, left_indexer, right_indexer = self._get_join_info()
#    1143 result = self._reindex_and_concat(join_index, left_indexer, right_indexer)
#    1145 if self.indicator:
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:1423, in _MergeOperation._get_join_info(self)
#    1419     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1420         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1421     )
#    1422 else:
# -> 1423     (left_indexer, right_indexer) = self._get_join_indexers()
#    1425     if self.right_index:
#    1426         if len(self.left) > 0:
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:1397, in _MergeOperation._get_join_indexers(self)
#    1395 # make mypy happy
#    1396 assert self.how != "asof"
# -> 1397 return get_join_indexers(
#    1398     self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1399 )
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:2110, in get_join_indexers(left_keys, right_keys, sort, how)
#    2108     _, lidx, ridx = left.join(right, how=how, return_indexers=True, sort=sort)
#    2109 else:
# -> 2110     lidx, ridx = get_join_indexers_non_unique(
#    2111         left._values, right._values, sort, how
#    2112     )
#    2114 if lidx is not None and is_range_indexer(lidx, len(left)):
#    2115     lidx = None
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:2144, in get_join_indexers_non_unique(left, right, sort, how)
#    2121 def get_join_indexers_non_unique(
#    2122     left: ArrayLike,
#    2123     right: ArrayLike,
#    2124     sort: bool = False,
#    2125     how: JoinHow = "inner",
#    2126 ) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp]]:
#    2127     """
#    2128     Get join indexers for left and right.
#    2129
#    (...)   2142         Indexer into right.
#    2143     """
# -> 2144     lkey, rkey, count = _factorize_keys(left, right, sort=sort, how=how)
#    2145     if count == -1:
#    2146         # hash join
#    2147         return lkey, rkey
#
# File ~/Desktop/Sigma Labs Coursework/Coursework-Advanced-Data-Week-5/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:2932, in _factorize_keys(lk, rk, sort, how)
#    2930         llab = rizer.factorize(lk_data, mask=lk_mask)
#    2931 else:
# -> 2932     llab = rizer.factorize(lk_data, mask=lk_mask)
#    2933     rlab = rizer.factorize(rk_data, mask=rk_mask)
#    2935 assert llab.dtype == np.dtype(np.intp), llab.dtype
#
# File pandas/_libs/hashtable.pyx:125, in pandas._libs.hashtable.ObjectFactorizer.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:7882, in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# File pandas/_libs/hashtable_class_helper.pxi:7783, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
